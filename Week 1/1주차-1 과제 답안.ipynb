# %% [markdown]
# # 1. 자료형 - 문자
#
# 1. 주민번호의 뒷자리 부분만 출력해보세요.
# 2. 힌트 : 이름[0:] 처럼 문자열을 원하는 부분만 고를 수 있습니다.
#
# ```
# # 출력
# 1234567
# ```

# %%
주민등록번호 = "123456-1234567"

### 이 사이에 코드 입력

뒷부분 = 주민등록번호[7:] # 이 코드를 수정

###

print(뒷부분)
# Out:
# 1234567

# %% [markdown]
# # 2. 리스트
# 1. 숫자를 정렬해서 출력해보세요.
# 2. 힌트 : .sort(), .reverse()
#
# ```
# # 출력
# [9, 8, 7, 6, 5, 4, 3, 2, 1]
# ```

# %%
numbers = [1, 3, 5, 7, 9, 2, 4, 6, 8]

### 이 사이에 코드 입력

numbers.sort()
numbers.reverse()

###

print(numbers)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# # 3. 제어문
# 1. 1~10까지의 값을 홀수를 제외하고 출력해보세요.
# 2. 힌트 : 반복문으로 1~10까지 반복하게 하고, if와 continue를 조합해보세요. 꼭 써야 하는 건 아닙니다.
#
# ```
# # 출력
# 2
# 4
# 6
# 8
# ```

# %%
### 이 사이에 코드 입력

for i in range(1, 11):
    if i % 2 == 1:
        continue
    print(i)

###
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# # 4. 반복문
# 1. for문을 사용해서 리스트의 모든 숫자를 sum에 더해보세요.
# 2. sum을 10으로 나누면 average가 됩니다.
#
# ```
# # 출력
# 835
# 83.5
# ```

# %%
scores = [80, 70, 60, 80, 75, 100, 100, 80, 90, 100]

sum = 0
average = 0

### 이 사이에 코드 입력

for score in scores:
    sum += score

average = sum / 10

###

print(sum)
print(average)
# Out:
# 835
# 83.5

# %% [markdown]
# # 5. 반복문
# 1. 구구단을 2단부터 9단까지 출력해보세요.
# 형식 : 2 * 2 = 4의 형태
# 2. 힌트 : print("{} * {} = {}".format(i, j, i * j))의 형태로 출력할 수 있습니다.
#
# ```
# # 출력
# 2 * 2 = 4
# 2 * 3 = 6
# ... 중간 생략 ...
# 9 * 8 = 72
# 9 * 9 = 81
# ```

# %%
### 이 사이에 코드 입력

for i in range(2, 10):
    for j in range(2, 10):
        print("{} * {} = {}".format(i, j, i * j))


###
# Out:
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81

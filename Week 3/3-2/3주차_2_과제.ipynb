# %%
import requests

def 다운로드(파일명, 링크):
    with open(파일명, "wb") as f:
        res = requests.get(링크)
        f.write(res.content)

파일명 = "연비.xlsx"
다운로드_링크 = "https://github.com/tyjeon24/keri-pythontraining/raw/main/Week%203/3-1/%EC%97%B0%EB%B9%84.xlsx"
다운로드(파일명, 다운로드_링크)

파일명 = "와이파이.xlsx"
다운로드_링크 = "https://github.com/tyjeon24/keri-pythontraining/raw/main/Week%203/3-2/%EC%B0%BD%EC%9B%90%EC%8B%9C_%EA%B3%B5%EA%B3%B5%EC%99%80%EC%9D%B4%ED%8C%8C%EC%9D%B4_20220308.xlsx"
다운로드(파일명, 다운로드_링크)

# %%
# 폰트 설정

# %matplotlib inline  

import os

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action='ignore') 

path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf' # 나눔 고딕

if not os.path.exists(path):
    # !apt-get update -qq
    # !apt-get install fonts-nanum* -qq

font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)
fm._rebuild()
print(font_name)

# 한글 폰트가 적용이 안 되는 경우 런타임 - 런타임 다시 시작을 눌러 재시작할 것.
# Out:
# NanumGothic

# %% [markdown]
# # 1. stripplot
#
# 1. 연비 데이터가 제공됩니다.
# 2. 국가별 연비를 나타내는 stripplot을 그려보세요.

# %%
import pandas as pd
import seaborn as sns
pd.options.display.float_format = '{:.2f}'.format # 소숫점 둘째자리까지 표현

### 이 사이에 코드 입력

###

# %% [markdown]
# # 2. boxplot
#
# 1. 연비 데이터 새로운 열 '배기량_100단위'를 추가해보세요.
# 2. 배기량_100단위 열은 기존의 배기량 데이터를 100으로 나눈 몫입니다.
# 3. 기존의 데이터를 가지고 배기량_100단위 열을 새로 만드세요.
# 4. 연비 데이터로 국가별 연비를 나타내는 boxplot을 만들되, col 파라미터에 배기량_100단위를 넣어 여러 차트를 표현해보세요.

# %%
import pandas as pd
import seaborn as sns
pd.options.display.float_format = '{:.2f}'.format # 소숫점 둘째자리까지 표현

### 이 사이에 코드 입력

###

# %% [markdown]
# # 3. folium
#
# 1. 창원시 와이파이 데이터가 제공됩니다.
# 2. 창원시 지도에 와이파이가 있는 곳을 나타내는 마커를 넣어보세요.

# %%
와이파이 = pd.read_excel("와이파이.xlsx")
와이파이
# Out:
#                 AP설치장소명       설치년월                         주소             통신사  \
# 0                  장미공원 2018-03-01        경상남도 창원시 성산구 가음동 31         KT(케이티)
# 1                기업사랑공원 2018-06-01      경상남도 창원시 성산구 가음정동 626         KT(케이티)
# 2                상남분수광장 2018-03-01        경상남도 창원시 성산구 상남동 24         KT(케이티)
# 3                  창원시청 2015-10-01      경상남도 창원시 의창구 중앙대로 151  SKB(에스케이브로드밴드)
# 4                 창원보건소 2017-04-01  경상남도 창원시 의창구 중앙대로 162번길 9  SKB(에스케이브로드밴드)
# ..                  ...        ...                        ...             ...
# 522  안골포초등학교(부영3차아파트방면) 2021-12-31       경상남도 창원시 진해구 안청북로 32         KT(케이티)
# 523                자은본동 2021-12-31    경상남도 창원시 진해구 자은동 696-14         KT(케이티)
# 524               자은포스코 2021-12-31     경상남도 창원시 진해구 자은동 779-5         KT(케이티)
# 525       웅천동(서중소류지 방면) 2021-12-31       경상남도 창원시 진해구 웅천로 173         KT(케이티)
# 526  자은프라임아파트(냉천중학교 방면) 2021-12-31       경상남도 창원시 진해구 자은동 121         KT(케이티)
#
#      AP대수    위도     경도
# 0    6.00 35.21 128.69
# 1    7.00 35.21 128.69
# 2    4.00 35.22 128.68
# 3   58.00 35.23 128.68
# 4   12.00 35.23 128.69
# ..    ...   ...    ...
# 522  1.00 35.10 128.81
# 523  1.00 35.14 128.71
# 524  1.00 35.14 128.71
# 525  1.00 35.11 128.75
# 526  1.00 35.15 128.72
#
# [527 rows x 7 columns]

# %%
import folium
창원광장 = [35.226367, 128.682232]

### 이 사이에 코드 입력
m = folium.Map(location=창원광장, zoom_start=12)

###

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_5bcc4aba431ca59e0d602d53da10e574 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_5bcc4aba431ca59e0d602d53da10e574&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_5bcc4aba431ca59e0d602d53da10e574 = L.map(
#         &#x27;map_5bcc4aba431ca59e0d602d53da10e574&#x27;, {
#         center: [35.226367, 128.682232],
#         zoom: 12,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_ecfb2c132bb4baa4b696041b7114d4e8 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#         var marker_55794f17069413e5edbcdaccc6efcac1 = L.marker(
#             [35.207397, 128.69031],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_381705b4b405254499718ce74af68ede = L.marker(
#             [35.209548, 128.686188],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_b3d2d888eb6a200833804c18aea50f8d = L.marker(
#             [35.221194, 128.682947],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_0452196ee227d6aae389e79979f4d168 = L.marker(
#             [35.228356, 128.682073],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_6d295d28628f0d4ab363f3ab0565f8ae = L.marker(
#             [35.227904, 128.685541],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_1f554bb7141af055cf5d6de94f0f2ed6 = L.marker(
#             [35.25739, 128.613159],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_196d1a219066373da2d01b67f1f6c01a = L.marker(
#             [35.332318, 128.708211],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_d85c394a8ec4d6aed6ee2bb1a01ca385 = L.marker(
#             [35.279717, 128.688659],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_37893c777b6dd632e8535f4500da1db4 = L.marker(
#             [35.347876, 128.607152],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_7442cc83698b459ac7daf42228fea4eb = L.marker(
#             [35.233512, 128.678974],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_1c614cba2347e9ed32eb99e4e981fa3f = L.marker(
#             [35.253122, 128.648511],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_a33c5f7cca5194b917d8001747375578 = L.marker(
#             [35.257319, 128.623532],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_5fdded693012568bfc916074a4339390 = L.marker(
#             [35.236, 128.654406],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_c59c924ffe25f1ea975c67f3964ec57a = L.marker(
#             [35.373486, 128.676347],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_c3a619e6ef0cbff76428e6270ff6f1c5 = L.marker(
#             [35.282317, 128.599858],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_db002b5f025f6be0b4cc023e500062a9 = L.marker(
#             [35.298689, 128.663234],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_8a50e3fcdea4b637cb77e38c27f4d40f = L.marker(
#             [35.243079, 128.64208],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_b65017da467b3376ee3466dd180a7c2d = L.marker(
#             [35.253816, 128.640154],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5bcc4aba431ca59e0d602d53da10e574);
#
#
#         var marker_8e5766abab077170f0e7c88b67639cb2 = L.marker(
#             [35.28471, 128.682446],
#             {
